# %% [markdown]
# <a href="https://colab.research.google.com/github/davidgvad/Tree-Classifier/blob/main/Tree_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p><img alt="Colaboratory logo" height="45px" src="/img/colab_favicon.ico" align="left" hspace="10px" vspace="0px"></p>
#
# <h1>What is Colaboratory?</h1>
#
# Colaboratory, or "Colab" for short, allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Free access to GPUs
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) to learn more, or just get started below!

# %% [markdown]
# ## **Getting started**
#
# The document you are reading is not a static web page, but an interactive environment called a **Colab notebook** that lets you write and execute code.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut "Command/Ctrl+Enter". To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Colab notebooks allow you to combine **executable code** and **rich text** in a single document, along with **images**, **HTML**, **LaTeX** and more. When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To learn more, see [Overview of Colab](/notebooks/basic_features_overview.ipynb). To create a new Colab notebook you can use the File menu above, or use the following link: [create a new Colab notebook](http://colab.research.google.com#create=true).
#
# Colab notebooks are Jupyter notebooks that are hosted by Colab. To learn more about the Jupyter project, see [jupyter.org](https://www.jupyter.org).

# %% [markdown]
# ## Data science
#
# With Colab you can harness the full power of popular Python libraries to analyze and visualize data. The code cell below uses **numpy** to generate some random data, and uses **matplotlib** to visualize it. To edit the code, just click the cell and start editing.

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %%
# -*- coding: utf-8 -*-
#qtdesigner
#pyuic5 –x "filename".ui –o "filename".py
# !pip install PyQt5
# Out:
# ...
#      |████████████████████████████████| 8.3 MB 5.4 MB/s
# ...
#      |████████████████████████████████| 317 kB 69.3 MB/s
# ...
#      |████████████████████████████████| 59.9 MB 53 kB/s
# ...

# %% [markdown]
# You can import your own data into Colab notebooks from your Google Drive account, including from spreadsheets, as well as from Github and many other sources. To learn more about importing data, and how Colab can be used for data science, see the links below under [Working with Data](#working-with-data).

# %% [markdown]
# ## Machine learning
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just [a few lines of code](https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb). Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including [GPUs and TPUs](#using-accelerated-hardware), regardless of the power of your machine. All you need is a browser.

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the [machine learning examples](#machine-learning-examples) below.

# %% [markdown]
# ## More Resources
#
# ### Working with Notebooks in Colab
# - [Overview of Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
# - <img src="/img/new.png" height="20px" align="left" hspace="4px" alt="New"></img>
#  [TensorFlow 2 in Colab](/notebooks/tensorflow_version.ipynb)
#
# <a name="working-with-data"></a>
# ### Working with Data
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# ### Machine Learning Crash Course
# These are a few of the notebooks from Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas](/notebooks/mlcc/intro_to_pandas.ipynb)
# - [Tensorflow concepts](/notebooks/mlcc/tensorflow_programming_concepts.ipynb)
#
# <a name="using-accelerated-hardware"></a>
# ### Using Accelerated Hardware
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TensorFlow with TPUs](/notebooks/tpu.ipynb)

# %% [markdown]
# <a name="machine-learning-examples"></a>
#
# ## Machine Learning Examples
#
# To see end-to-end examples of the interactive machine learning analyses that Colaboratory makes possible, check out these  tutorials using models from [TensorFlow Hub](https://tfhub.dev).
#
# A few featured examples:
#
# - [Retraining an Image Classifier](https://tensorflow.org/hub/tutorials/tf2_image_retraining): Build a Keras model on top of a pre-trained image classifier to distinguish flowers.
# - [Text Classification](https://tensorflow.org/hub/tutorials/tf2_text_classification): Classify IMDB movie reviews as either *positive* or *negative*.
# - [Style Transfer](https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization): Use deep learning to transfer style between images.
# - [Multilingual Universal Sentence Encoder Q&A](https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa): Use a machine learning model to answer questions from the SQuAD dataset.
# - [Video Interpolation](https://tensorflow.org/hub/tutorials/tweening_conv3d): Predict what happened in a video between the first and the last frame.

# %%
import pandas as pd
import io
from io import StringIO
import string
import pandas as pd
from collections import Counter

try:
    from StringIO import StringIO
except ImportError:
    from io import StringIO
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-6e05a9e2-536c-468a-a36e-1ee16edef42b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6e05a9e2-536c-468a-a36e-1ee16edef42b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving KDDTest - Copy (2).csv to KDDTest - Copy (2) (1).csv

# %%
df=pd.read_excel(io.BytesIO(uploaded["KDDTest - Copy (2).csv"]),header=None)
df.dropna(inplace=True,axis=1)
df
# Out:
#            0                                       1   ... 86       87
# 0      186059   172.16.0.5-192.168.50.1-58445-4463-17  ...  1  UDP-lag
# 1      135692   172.16.0.5-192.168.50.1-36908-9914-17  ...  1  UDP-lag
# 2       33822  172.16.0.5-192.168.50.1-41727-32361-17  ...  1  UDP-lag
# 3       24498   172.16.0.5-192.168.50.1-55447-5691-17  ...  1  UDP-lag
# 4      117372  172.16.0.5-192.168.50.1-58794-56335-17  ...  1  UDP-lag
# ...       ...                                     ...  ... ..      ...
# 53390   15665   172.16.0.5-192.168.50.1-46179-52886-6  ...  1     TFTP
# 53391   23164   172.16.0.5-192.168.50.1-46180-49712-6  ...  1     TFTP
# 53392  179334   172.16.0.5-192.168.50.1-44113-44113-6  ...  1     TFTP
# 53393  140625   172.16.0.5-192.168.50.1-20945-20945-6  ...  1     TFTP
# 53394   88902   172.16.0.5-192.168.50.1-46181-18273-6  ...  1     TFTP
#
# [53395 rows x 87 columns]

# %%
import pandas as pd
import io
from io import StringIO
import string
import pandas as pd
from collections import Counter

try:
    from StringIO import StringIO
except ImportError:
    from io import StringIO
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-9898c85b-77ac-4976-b5e4-0431544f10ae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9898c85b-77ac-4976-b5e4-0431544f10ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving KDDTest - Copy.csv to KDDTest - Copy.csv

# %%
kf=pd.read_excel(io.BytesIO(uploaded["KDDTest - Copy.csv"]),header=None)
kf.dropna(inplace=True,axis=1)
kf
# Out:
#        1    2         3    4      5     6   ...    38   39    40    41       42  43
# 0       0  tcp      http   S0      0     0  ...  0.00  0.0  0.00  0.00  neptune  21
# 1       0  tcp      http   S0      0     0  ...  1.00  1.0  0.00  0.00  neptune  21
# 2       0  tcp      http   S0      0     0  ...  1.00  1.0  0.00  0.00  neptune  21
# 3       0  tcp      http   S0      0     0  ...  1.00  1.0  0.00  0.00  neptune  21
# 4       0  tcp      http   S0      0     0  ...  1.00  1.0  0.00  0.00  neptune  21
# ...    ..  ...       ...  ...    ...   ...  ...   ...  ...   ...   ...      ...  ..
# 22539   0  tcp      smtp   SF    794   333  ...  0.01  0.0  0.00  0.00   normal  21
# 22540   0  tcp      http   SF    317   938  ...  0.01  0.0  0.00  0.00   normal  21
# 22541   0  tcp      http   SF  54540  8314  ...  0.00  0.0  0.07  0.07     back  15
# 22542   0  udp  domain_u   SF     42    42  ...  0.00  0.0  0.00  0.00   normal  21
# ...

# %%
import random as rd
df.columns = ['Unnamed: 0','Flow ID',' Source IP',' Source Port',' Destination IP',' Destination Port',' Protocol',' Timestamp',' Flow Duration',' Total Fwd Packets',' Total Backward Packets','Total Length of Fwd Packets', 'Total Length of Bwd Packets',' Fwd Packet Length Max',' Fwd Packet Length Min',' Fwd Packet Length Mean',' Fwd Packet Length Std','Bwd Packet Length Max',' Bwd Packet Length Min',' Bwd Packet Length Mean',' Bwd Packet Length Std',' Flow Packets/s',' Flow IAT Mean',' Flow IAT Std',' Flow IAT Max',' Flow IAT Min','Fwd IAT Total',' Fwd IAT Mean',' Fwd IAT Std',' Fwd IAT Max',' Fwd IAT Min','Bwd IAT Total',' Bwd IAT Mean',' Bwd IAT Std',' Bwd IAT Max',' Bwd IAT Min','Fwd PSH Flags',' Bwd PSH Flags',' Fwd URG Flags',' Bwd URG Flags',' Fwd Header Length',' Bwd Header Length','Fwd Packets/s',' Bwd Packets/s',' Min Packet Length',' Max Packet Length',' Packet Length Mean',' Packet Length Std',' Packet Length Variance','FIN Flag Count',' SYN Flag Count',' RST Flag Count',' PSH Flag Count',' ACK Flag Count',' URG Flag Count',' CWE Flag Count',' ECE Flag Count',' Down/Up Ratio',' Average Packet Size',' Avg Fwd Segment Size',' Avg Bwd Segment Size',' Fwd Header Length.1','Fwd Avg Bytes/Bulk',' Fwd Avg Packets/Bulk',' Fwd Avg Bulk Rate',' Bwd Avg Bytes/Bulk',' Bwd Avg Packets/Bulk','Bwd Avg Bulk Rate','Subflow Fwd Packets',' Subflow Fwd Bytes',' Subflow Bwd Packets',' Subflow Bwd Bytes','Init_Win_bytes_forward',' Init_Win_bytes_backward',' act_data_pkt_fwd',' min_seg_size_forward','Active Mean',' Active Std',' Active Max',' Active Min','Idle Mean',' Idle Std',' Idle Max',' Idle Min','SimillarHTTP',' Inbound',' Label']

# %%
kf.columns = [
    'duration',
    'protocol_type',
    'service',
    'flag',
    'src_bytes',
    'dst_bytes',
    'land',
    'wrong_fragment',
    'urgent',
    'hot',
    'num_failed_logins',
    'logged_in',
    'num_compromised',
    'root_shell',
    'su_attempted',
    'num_root',
    'num_file_creations',
    'num_shells',
    'num_access_files',
    'num_outbound_cmds',
    'is_host_login',
    'is_guest_login',
    'count',
    'srv_count',
    'serror_rate',
    'srv_serror_rate',
    'rerror_rate',
    'srv_rerror_rate',
    'same_srv_rate',
    'diff_srv_rate',
    'srv_diff_host_rate',
    'dst_host_count',
    'dst_host_srv_count',
    'dst_host_same_srv_rate',
    'dst_host_diff_srv_rate',
    'dst_host_same_src_port_rate',
    'dst_host_srv_diff_host_rate',
    'dst_host_serror_rate',
    'dst_host_srv_serror_rate',
    'dst_host_rerror_rate',
    'dst_host_srv_rerror_rate',
    'outcome',
    'new'
]

# %%
def encode_numeric_zscore(df, name, mean=None, sd=None):
    if mean is None:
        mean = df[name].mean()

    if sd is None:
        sd = df[name].std()

    df[name] = (df[name] - mean) / sd
def encode_text_dummy(df, name):
		  dummies = pd.get_dummies(df[name])
		  for x in dummies.columns:
		      dummy_name = str(name)+ "-" +str(x)
		      df[dummy_name] = dummies[x]
def encode_text_dummy(df, name):
		  dummies = pd.get_dummies(df[name])
		  for x in dummies.columns:
		      dummy_name = str(name)+ "-" +str(x)
		      df[dummy_name] = dummies[x]
		  df.drop(name, axis=1, inplace=True)



encode_numeric_zscore(df, 'Unnamed: 0')
encode_numeric_zscore(df, ' Source Port')
encode_numeric_zscore(df, ' Destination Port')
encode_numeric_zscore(df, ' Protocol')
encode_numeric_zscore(df, ' Flow Duration')
encode_numeric_zscore(df, ' Total Fwd Packets')
encode_numeric_zscore(df, ' Total Backward Packets')
encode_numeric_zscore(df, 'Total Length of Fwd Packets')
encode_numeric_zscore(df, ' Fwd Packet Length Max')
encode_numeric_zscore(df, ' Fwd Packet Length Min')
encode_numeric_zscore(df, ' Fwd Packet Length Mean')
encode_numeric_zscore(df, ' Fwd Packet Length Std')
encode_numeric_zscore(df, ' Flow IAT Mean')
encode_numeric_zscore(df, ' Flow IAT Std')
encode_numeric_zscore(df, ' Flow IAT Max')
encode_numeric_zscore(df, ' Flow IAT Min')
encode_numeric_zscore(df, 'Fwd IAT Total')
encode_numeric_zscore(df, ' Fwd IAT Mean')
encode_numeric_zscore(df, ' Fwd IAT Std')
encode_numeric_zscore(df, ' Fwd IAT Max')
encode_numeric_zscore(df, ' Fwd IAT Min')
encode_numeric_zscore(df, 'Bwd IAT Total')
encode_numeric_zscore(df, ' Bwd IAT Mean')
encode_numeric_zscore(df, ' Bwd IAT Std')
encode_numeric_zscore(df, ' Bwd IAT Max')
encode_numeric_zscore(df, ' Bwd IAT Min')
encode_numeric_zscore(df, 'Fwd PSH Flags')
encode_numeric_zscore(df, ' Bwd PSH Flags')
encode_numeric_zscore(df, ' Fwd URG Flags')
encode_numeric_zscore(df, ' Bwd URG Flags')
encode_numeric_zscore(df, ' Fwd Header Length')
encode_numeric_zscore(df, ' Bwd Header Length')
encode_numeric_zscore(df, 'Fwd Packets/s')
encode_numeric_zscore(df, ' Bwd Packets/s')
encode_numeric_zscore(df, ' Min Packet Length')
encode_numeric_zscore(df, ' Max Packet Length')
encode_numeric_zscore(df, ' Packet Length Mean')
encode_numeric_zscore(df, ' Packet Length Std')
encode_numeric_zscore(df, ' Packet Length Variance')
encode_numeric_zscore(df, 'FIN Flag Count')
encode_numeric_zscore(df, ' SYN Flag Count')
encode_numeric_zscore(df, ' RST Flag Count')
encode_numeric_zscore(df, ' PSH Flag Count')
encode_numeric_zscore(df, ' ACK Flag Count')
encode_numeric_zscore(df, ' URG Flag Count')
encode_numeric_zscore(df, ' CWE Flag Count')
encode_numeric_zscore(df, ' ECE Flag Count')
encode_numeric_zscore(df, ' Down/Up Ratio')
encode_numeric_zscore(df, ' Average Packet Size')
encode_numeric_zscore(df, ' Avg Fwd Segment Size')
encode_numeric_zscore(df, ' Avg Bwd Segment Size')
encode_numeric_zscore(df, ' Fwd Header Length.1')
encode_numeric_zscore(df, 'Fwd Avg Bytes/Bulk')
encode_numeric_zscore(df, ' Fwd Avg Packets/Bulk')
encode_numeric_zscore(df, ' Fwd Avg Bulk Rate')
encode_numeric_zscore(df, ' Bwd Avg Bytes/Bulk')
encode_numeric_zscore(df, ' Bwd Avg Packets/Bulk')
encode_numeric_zscore(df, 'Bwd Avg Bulk Rate')
encode_numeric_zscore(df, 'Subflow Fwd Packets')
encode_numeric_zscore(df, ' Subflow Fwd Bytes')
encode_numeric_zscore(df, ' Subflow Bwd Packets')
encode_numeric_zscore(df, ' Subflow Bwd Bytes')
encode_numeric_zscore(df, 'Init_Win_bytes_forward')
encode_numeric_zscore(df, ' Init_Win_bytes_backward')
encode_numeric_zscore(df, ' act_data_pkt_fwd')
encode_numeric_zscore(df, ' min_seg_size_forward')
encode_numeric_zscore(df, 'Active Mean')
encode_numeric_zscore(df, ' Active Std')
encode_numeric_zscore(df, ' Active Max')
encode_numeric_zscore(df, ' Active Min')
encode_numeric_zscore(df, 'Idle Mean')
encode_numeric_zscore(df, ' Idle Std')
encode_numeric_zscore(df, ' Idle Max')
encode_numeric_zscore(df, ' Idle Min')
encode_numeric_zscore(df, ' Inbound')
df.dropna(inplace=True,axis=1)
df
# Out:
#        Unnamed: 0                                 Flow ID  ...   Inbound    Label
# 0        0.714181   172.16.0.5-192.168.50.1-58445-4463-17  ...  0.389863  UDP-lag
# 1        0.351215   172.16.0.5-192.168.50.1-36908-9914-17  ...  0.389863  UDP-lag
# 2       -0.382903  172.16.0.5-192.168.50.1-41727-32361-17  ...  0.389863  UDP-lag
# 3       -0.450095   172.16.0.5-192.168.50.1-55447-5691-17  ...  0.389863  UDP-lag
# 4        0.219194  172.16.0.5-192.168.50.1-58794-56335-17  ...  0.389863  UDP-lag
# ...           ...                                     ...  ...       ...      ...
# 53390   -0.513750   172.16.0.5-192.168.50.1-46179-52886-6  ...  0.389863     TFTP
# 53391   -0.459709   172.16.0.5-192.168.50.1-46180-49712-6  ...  0.389863     TFTP
# 53392    0.665718   172.16.0.5-192.168.50.1-44113-44113-6  ...  0.389863     TFTP
# 53393    0.386765   172.16.0.5-192.168.50.1-20945-20945-6  ...  0.389863     TFTP
# ...

# %%
def encode_numeric_zscore(df, name, mean=None, sd=None):
    if mean is None:
        mean = df[name].mean()

    if sd is None:
        sd = df[name].std()

    df[name] = (df[name] - mean) / sd

# Encode text values to dummy variables(i.e. [1,0,0],
# [0,1,0],[0,0,1] for red,green,blue)
def encode_text_dummy(df, name):
		  dummies = pd.get_dummies(df[name])
		  for x in dummies.columns:
		      dummy_name = str(name)+ "-" +str(x)
		      df[dummy_name] = dummies[x]
		  df.drop(name, axis=1, inplace=True)
encode_numeric_zscore(kf, 'duration')
encode_numeric_zscore(kf, 'src_bytes')
encode_numeric_zscore(kf, 'dst_bytes')
encode_numeric_zscore(kf, 'land')
encode_numeric_zscore(kf, 'wrong_fragment')
encode_numeric_zscore(kf, 'urgent')
encode_numeric_zscore(kf, 'hot')
encode_numeric_zscore(kf, 'num_failed_logins')
encode_numeric_zscore(kf, 'logged_in')
encode_numeric_zscore(kf, 'num_compromised')
encode_numeric_zscore(kf, 'root_shell')
encode_numeric_zscore(kf, 'su_attempted')
encode_numeric_zscore(kf, 'num_root')
encode_numeric_zscore(kf, 'num_file_creations')
encode_numeric_zscore(kf, 'num_shells')
encode_numeric_zscore(kf, 'num_access_files')
encode_numeric_zscore(kf, 'num_outbound_cmds')
encode_numeric_zscore(kf, 'is_host_login')
encode_numeric_zscore(kf, 'is_guest_login')
encode_numeric_zscore(kf, 'count')
encode_numeric_zscore(kf, 'srv_count')
encode_numeric_zscore(kf, 'serror_rate')
encode_numeric_zscore(kf, 'srv_serror_rate')
encode_numeric_zscore(kf, 'rerror_rate')
encode_numeric_zscore(kf, 'srv_rerror_rate')
encode_numeric_zscore(kf, 'same_srv_rate')
encode_numeric_zscore(kf, 'diff_srv_rate')
encode_numeric_zscore(kf, 'srv_diff_host_rate')
encode_numeric_zscore(kf, 'dst_host_count')
encode_numeric_zscore(kf, 'dst_host_srv_count')
encode_numeric_zscore(kf, 'dst_host_same_srv_rate')
encode_numeric_zscore(kf, 'dst_host_diff_srv_rate')
encode_numeric_zscore(kf, 'dst_host_same_src_port_rate')
encode_numeric_zscore(kf, 'dst_host_srv_diff_host_rate')
encode_numeric_zscore(kf, 'dst_host_serror_rate')
encode_numeric_zscore(kf, 'dst_host_srv_serror_rate')
encode_numeric_zscore(kf, 'dst_host_rerror_rate')
encode_numeric_zscore(kf, 'dst_host_srv_rerror_rate')
df.dropna(inplace=True,axis=1)

# %%
a=pd.get_dummies(kf['protocol_type'])
b=pd.get_dummies(kf['service'])
c=pd.get_dummies(kf['flag'])
kf=pd.concat((kf,a,b,c),axis=1)

# %%
kf.pop('protocol_type')
kf.pop('service')
kf.pop('flag')
# Out:
# 0         S0
# 1         S0
# 2         S0
# 3         S0
# 4         S0
#         ...
# 22539     SF
# 22540     SF
# 22541     SF
# 22542     SF
# 22543    REJ
# Name: flag, Length: 22544, dtype: object

# %%
e=pd.get_dummies(df[' Timestamp'])
f=pd.get_dummies(df[' Destination IP'])
g=pd.get_dummies(df['SimillarHTTP'])
h=pd.get_dummies(df[' Source IP'])
df=pd.concat((df,e,f,g,h),axis=1)

# %%
df.pop('Flow ID')
df.pop(' Source IP')
df.pop(' Destination IP')
df.pop(' Timestamp')
df.pop('SimillarHTTP')
df.pop(' Flow Packets/s')
df
# Out:
#        Unnamed: 0   Source Port  ...  94.31.29.44  96.6.27.46
# 0        0.714181      1.299256  ...            0           0
# 1        0.351215      0.448466  ...            0           0
# 2       -0.382903      0.638834  ...            0           0
# 3       -0.450095      1.180824  ...            0           0
# 4        0.219194      1.313043  ...            0           0
# ...           ...           ...  ...          ...         ...
# 53390   -0.513750      0.814704  ...            0           0
# 53391   -0.459709      0.814744  ...            0           0
# 53392    0.665718      0.733090  ...            0           0
# 53393    0.386765     -0.182131  ...            0           0
# 53394    0.014027      0.814783  ...            0           0
#
# [53395 rows x 4604 columns]

# %%
k=0
for i in df.columns:
  k=k+1
  if k>2200:
    df.pop(i)

# %%
import numpy as np
x=df.values
y=df[' Label'].values
x=np.delete(x,68,axis=1)
k=0
for i in df.columns:
  if i!=' Label':
    k=k+1
  if i==' Label':
    break
print(k)
print(x)
# Out:
# 68
# [[0.7141811760039114 1.2992559325030872 -1.176077035435497 ... 0 0 0]
#  [0.351215428003322 0.44846588741272436 -0.91728030122784 ... 0 0 0]
#  [-0.3829025609342769 0.6388339622277153 0.1484343002690006 ... 0 0 0]
#  ...
#  [0.6657180025906851 0.7330896639310911 0.7063831574343622 ... 0 0 0]
#  [0.3867646970661391 -0.18213082938986935 -0.3935623091081069 ... 0 0 0]
#  [0.014027043764682053 0.8147832058936146 -0.5204206605670795 ... 0 0 0]]

# %%
import numpy as np
x=kf.values
y=kf['outcome'].values
x=np.delete(x,37,axis=1)
k=0
for i in kf.columns:
  if i!='outcome':
    k=k+1
  if i=='outcome':
    break

# %%
from sklearn.model_selection import train_test_split
from sklearn import tree
import time
j=[]
def intelect(x,y,m):
  g=''
  start = time.perf_counter()
  x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=m,random_state=0)
  dt_clf=tree.DecisionTreeClassifier(max_depth=1000)
  dt_clf.fit(x_train,y_train)
  finish = time.perf_counter()
  a=['Fitting with ',m,' amount of training data was Finished in', round(finish-start, 2), 'second(s)']
  start = time.perf_counter()
  y_pred=dt_clf.predict(x_test)
  print('accurcay of ',m,' amount of training data ',dt_clf.score(x_test,y_test))
  finish = time.perf_counter()
  o=str(m)
  b=['predicting and calculating accuracy of ',o,' amount of training data was Finished in', round(finish-start, 2), 'second(s)']
  c=''
  for i in b:
    c=c+str(i)
    c=c+" "
  c=c+'. '
  for i in a:
    g=g+str(i)
    g=g+' '
  g=g+'. '
  print(g)
  print(c)
  print('-----------------------------------')

# %%
import concurrent.futures
import time
start = time.perf_counter()
import threading
threads=[]
t = threading.Thread(target=intelect, args=[x,y,0.1])
t.start()
threads.append(t)
t1 = threading.Thread(target=intelect, args=[x,y,0.2])
t1.start()
threads.append(t1)
t2 = threading.Thread(target=intelect, args=[x,y,0.3])
t2.start()
t3 = threading.Thread(target=intelect, args=[x,y,0.5])
t3.start()
t4 = threading.Thread(target=intelect, args=[x,y,0.6])
t4.start()
t6 = threading.Thread(target=intelect, args=[x,y,0.7])
t6.start()
t7 = threading.Thread(target=intelect, args=[x,y,0.8])
t7.start()
t5 = threading.Thread(target=intelect, args=[x,y,0.99])
t5.start()
a=t.join()
b=t1.join()
c=t2.join()
d=t3.join()
e=t4.join()
f=t5.join()
g=t6.join()
h=t7.join()
print(a,b,c,d,e,f,g,h,i)

# %%
t1 = threading.Thread(target=intelect, args=[x,y,0.9])
t1.start()
threads.append(t1)
t2 = threading.Thread(target=intelect, args=[x,y,0.95])
t2.start()
t3 = threading.Thread(target=intelect, args=[x,y,0.4])
i=t1.join()
j=t2.join()
p=t3.join()
print(i,j,p)
finish = time.perf_counter()
print('The whole session finished in', round(finish-start, 2), 'second(s)')
# Out:
# accurcay of  0.95  amount of training data  0.9326972361313725
# Fitting with  0.95  amount of training data was Finished in 56.0 second(s) .
# predicting and calculating accuracy of  0.95  amount of training data was Finished in 9.83 second(s) .
# -----------------------------------
# accurcay of  0.9  amount of training data  0.9561345097386382
# Fitting with  0.9  amount of training data was Finished in 62.6 second(s) .
# predicting and calculating accuracy of  0.9  amount of training data was Finished in 6.77 second(s) .
# -----------------------------------
# The whole session finished in 350.55 second(s)

# %%
t = threading.Thread(target=intelect, args=[x,y,0.1])
t.start()
threads.append(t)
t1 = threading.Thread(target=intelect, args=[x,y,0.2])
t1.start()
threads.append(t1)
t2 = threading.Thread(target=intelect, args=[x,y,0.3])
t2.start()
t3 = threading.Thread(target=intelect, args=[x,y,0.5])
t3.start()
t4 = threading.Thread(target=intelect, args=[x,y,0.6])
t4.start()
t6 = threading.Thread(target=intelect, args=[x,y,0.7])
t6.start()
t7 = threading.Thread(target=intelect, args=[x,y,0.8])
t7.start()
t5 = threading.Thread(target=intelect, args=[x,y,0.9])
t5.start()
t8 = threading.Thread(target=intelect, args=[x,y,0.95])
t8.start()
t9 = threading.Thread(target=intelect, args=[x,y,0.99])
t9.start()
a=t.join()
b=t1.join()
c=t2.join()
d=t3.join()
e=t4.join()
f=t5.join()
g=t6.join()
h=t7.join()
i=t8.join()
j=t9.join()
finish = time.perf_counter()

print('Finished in', round(finish-start, 2), 'second(s)')
# Out:
# 0.9889135254988913
# 0.9463043376756782
# 0.8783995698732022
# 0.9891328454202706
# 0.9863378282469837
# 0.9753825681969395
# 0.982257706808605
# 0.9889118864577173
# 0.9703302119270577
# 0.9787719409416387
# Finished in 305.64 second(s)

# %%
import time
sd= time.perf_counter()
data=[]

# %%
start = time.perf_counter()
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=0)
from sklearn import ensemble
rf=ensemble.RandomForestClassifier(n_estimators=250)
rf.fit(x_train,y_train)
finish = time.perf_counter()
key=round(finish-start, 2)
start = time.perf_counter()
hg=rf.predict(x_test)
i=rf.score(x_test,y_test)
finish = time.perf_counter()
key2=round(finish-start, 2)
data.append([0.9,0.1,key,key2,i])
# Out:
# 0.9870786516853932

# %%
start = time.perf_counter()
from sklearn import tree
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=0)
dt_clf=tree.DecisionTreeClassifier(max_depth=1000)
dt_clf.fit(x_train,y_train)
finish = time.perf_counter()
key=round(finish-start, 2)
start = time.perf_counter()
y_pred=dt_clf.predict(x_test)
i=dt_clf.score(x_test,y_test)
finish = time.perf_counter()
key2=round(finish-start, 2)
data.append([0.9,0.1,key,key2,i])

# %%
start = time.perf_counter()
from sklearn import tree
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
dt_clf=tree.DecisionTreeClassifier(max_depth=1000)
dt_clf.fit(x_train,y_train)
finish = time.perf_counter()
key=round(finish-start, 2)
start = time.perf_counter()
y_pred=dt_clf.predict(x_test)
i=dt_clf.score(x_test,y_test)
finish = time.perf_counter()t
data.append([0.8,0.2,key,key2,i])

# %%
start = time.perf_counter()
from sklearn import tree
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)
dt_clf=tree.DecisionTreeClassifier(max_depth=1000)
dt_clf.fit(x_train,y_train)
finish = time.perf_counter()
key=round(finish-start, 2)
start = time.perf_counter()
y_pred=dt_clf.predict(x_test)
i=dt_clf.score(x_test,y_test)
finish = time.perf_counter()
key2=round(finish-start, 2)
data.append([0.7,0.3,key,key2,i])

# %%
start = time.perf_counter()
from sklearn import tree
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=0)
dt_clf=tree.DecisionTreeClassifier(max_depth=1000)
dt_clf.fit(x_train,y_train)
finish = time.perf_counter()
key=round(finish-start, 2)
start = time.perf_counter()
y_pred=dt_clf.predict(x_test)
i=dt_clf.score(x_test,y_test)
finish = time.perf_counter()
key2=round(finish-start, 2)
data.append([0.6,0.4,key,key2,i])

# %%
start = time.perf_counter()
from sklearn import tree
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5,random_state=0)
dt_clf=tree.DecisionTreeClassifier(max_depth=1000)
dt_clf.fit(x_train,y_train)
finish = time.perf_counter()
key=round(finish-start, 2)
start = time.perf_counter()
y_pred=dt_clf.predict(x_test)
i=dt_clf.score(x_test,y_test)
finish = time.perf_counter()
key2=round(finish-start, 2)
data.append([0.5,0.5,key,key2,i])

# %%
start = time.perf_counter()
from sklearn import tree
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.6,random_state=0)
dt_clf=tree.DecisionTreeClassifier(max_depth=1000)
dt_clf.fit(x_train,y_train)
finish = time.perf_counter()
key=round(finish-start, 2)
start = time.perf_counter()
y_pred=dt_clf.predict(x_test)
i=dt_clf.score(x_test,y_test)
finish = time.perf_counter()
key2=round(finish-start, 2)
data.append([0.4,0.6,key,key2,i])

# %%
start = time.perf_counter()
from sklearn import tree
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.7,random_state=0)
dt_clf=tree.DecisionTreeClassifier(max_depth=1000)
dt_clf.fit(x_train,y_train)
finish = time.perf_counter()
key=round(finish-start, 2)
start = time.perf_counter()
y_pred=dt_clf.predict(x_test)
i=dt_clf.score(x_test,y_test)
finish = time.perf_counter()
key2=round(finish-start, 2)
data.append([0.3,0.7,key,key2,i])

# %%
start = time.perf_counter()
from sklearn import tree
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.8,random_state=0)
dt_clf=tree.DecisionTreeClassifier(max_depth=1000)
dt_clf.fit(x_train,y_train)
finish = time.perf_counter()
key=round(finish-start, 2)
start = time.perf_counter()
y_pred=dt_clf.predict(x_test)
i=dt_clf.score(x_test,y_test)
finish = time.perf_counter()
key2=round(finish-start, 2)
data.append([0.2,0.8,key,key2,i])

# %%
start = time.perf_counter()
from sklearn import tree
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.9,random_state=0)
dt_clf=tree.DecisionTreeClassifier(max_depth=1000)
dt_clf.fit(x_train,y_train)
finish = time.perf_counter()
key=round(finish-start, 2)
start = time.perf_counter()
y_pred=dt_clf.predict(x_test)
i=dt_clf.score(x_test,y_test)
finish = time.perf_counter()
key2=round(finish-start, 2)
data.append([0.1,0.9,key,key2,i])

# %%
start = time.perf_counter()
from sklearn import tree
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.95,random_state=0)
dt_clf=tree.DecisionTreeClassifier(max_depth=1000)
dt_clf.fit(x_train,y_train)
finish = time.perf_counter()
key=round(finish-start, 2)
start = time.perf_counter()
y_pred=dt_clf.predict(x_test)
i=dt_clf.score(x_test,y_test)
finish = time.perf_counter()
key2=round(finish-start, 2)
data.append([0.05,0.95,key,key2,i])

# %%
start = time.perf_counter()
from sklearn import tree
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.99,random_state=0)
dt_clf=tree.DecisionTreeClassifier(max_depth=1000)
dt_clf.fit(x_train,y_train)
finish = time.perf_counter()
key=round(finish-start, 2)
start = time.perf_counter()
y_pred=dt_clf.predict(x_test)
i=dt_clf.score(x_test,y_test)
finish = time.perf_counter()
key2=round(finish-start, 2)
data.append([0.01,0.99,key,key2,i])

# %%
start = time.perf_counter()
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=0)
from sklearn import ensemble
rf=ensemble.RandomForestClassifier(n_estimators=250)
rf.fit(x_train,y_train)
finish = time.perf_counter()
key=round(finish-start, 2)
start = time.perf_counter()
hg=rf.predict(x_test)
i=rf.score(x_test,y_test)
finish = time.perf_counter()
key2=round(finish-start, 2)
data.append([0.9,0.1,key,key2,i])

# %%
start = time.perf_counter()
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
from sklearn import ensemble
rf=ensemble.RandomForestClassifier(n_estimators=250)
rf.fit(x_train,y_train)
finish = time.perf_counter()
key=round(finish-start, 2)
start = time.perf_counter()
hg=rf.predict(x_test)
i=rf.score(x_test,y_test)
finish = time.perf_counter()
key2=round(finish-start, 2)
data.append([0.8,0.2,key,key2,i])

# %%
start = time.perf_counter()
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)
from sklearn import ensemble
rf=ensemble.RandomForestClassifier(n_estimators=250)
rf.fit(x_train,y_train)
finish = time.perf_counter()
key=round(finish-start, 2)
start = time.perf_counter()
hg=rf.predict(x_test)
i=rf.score(x_test,y_test)
finish = time.perf_counter()
key2=round(finish-start, 2)
data.append([0.7,0.3,key,key2,i])

# %%
start = time.perf_counter()
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=0)
from sklearn import ensemble
rf=ensemble.RandomForestClassifier(n_estimators=250)
rf.fit(x_train,y_train)
finish = time.perf_counter()
key=round(finish-start, 2)
start = time.perf_counter()
hg=rf.predict(x_test)
i=rf.score(x_test,y_test)
finish = time.perf_counter()
key2=round(finish-start, 2)
data.append([0.6,0.4,key,key2,i])

# %%
start = time.perf_counter()
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5,random_state=0)
from sklearn import ensemble
rf=ensemble.RandomForestClassifier(n_estimators=250)
rf.fit(x_train,y_train)
finish = time.perf_counter()
key=round(finish-start, 2)
start = time.perf_counter()
hg=rf.predict(x_test)
i=rf.score(x_test,y_test)
finish = time.perf_counter()
key2=round(finish-start, 2)
data.append([0.5,0.5,key,key2,i])

# %%
start = time.perf_counter()
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.6,random_state=0)
from sklearn import ensemble
rf=ensemble.RandomForestClassifier(n_estimators=250)
rf.fit(x_train,y_train)
finish = time.perf_counter()
key=round(finish-start, 2)
start = time.perf_counter()
hg=rf.predict(x_test)
i=rf.score(x_test,y_test)
finish = time.perf_counter()
key2=round(finish-start, 2)
data.append([0.4,0.6,key,key2,i])

# %%
start = time.perf_counter()
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.7,random_state=0)
from sklearn import ensemble
rf=ensemble.RandomForestClassifier(n_estimators=250)
rf.fit(x_train,y_train)
finish = time.perf_counter()
key=round(finish-start, 2)
start = time.perf_counter()
hg=rf.predict(x_test)
i=rf.score(x_test,y_test)
finish = time.perf_counter()
key2=round(finish-start, 2)
data.append([0.3,0.7,key,key2,i])

# %%
start = time.perf_counter()
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.8,random_state=0)
from sklearn import ensemble
rf=ensemble.RandomForestClassifier(n_estimators=250)
rf.fit(x_train,y_train)
finish = time.perf_counter()
key=round(finish-start, 2)
start = time.perf_counter()
hg=rf.predict(x_test)
i=rf.score(x_test,y_test)
finish = time.perf_counter()
key2=round(finish-start, 2)
data.append([0.2,0.8,key,key2,i])

# %%
start = time.perf_counter()
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.9,random_state=0)
from sklearn import ensemble
rf=ensemble.RandomForestClassifier(n_estimators=250)
rf.fit(x_train,y_train)
finish = time.perf_counter()
key=round(finish-start, 2)
start = time.perf_counter()
hg=rf.predict(x_test)
i=rf.score(x_test,y_test)
finish = time.perf_counter()
key2=round(finish-start, 2)
data.append([0.1,0.9,key,key2,i])

# %%
start = time.perf_counter()
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.95,random_state=0)
from sklearn import ensemble
rf=ensemble.RandomForestClassifier(n_estimators=250)
rf.fit(x_train,y_train)
finish = time.perf_counter()
key=round(finish-start, 2)
start = time.perf_counter()
hg=rf.predict(x_test)
i=rf.score(x_test,y_test)
finish = time.perf_counter()
key2=round(finish-start, 2)
data.append([0.005,0.95,key,key2,i])

# %%
start = time.perf_counter()
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.99,random_state=0)
from sklearn import ensemble
rf=ensemble.RandomForestClassifier(n_estimators=250)
rf.fit(x_train,y_train)
finish = time.perf_counter()
key=round(finish-start, 2)
start = time.perf_counter()
hg=rf.predict(x_test)
i=rf.score(x_test,y_test)
finish = time.perf_counter()
key2=round(finish-start, 2)
data.append([0.01,0.99,key,key2,i])

# %%
omg = time.perf_counter()
print('Full session finished in', round(omg-sd, 2), 'second(s)')
df1 = pd.DataFrame(data, columns = ['train data size','test data size', '  time for learning dataset','  time for predicting and calculating','  accuracy'])
df1
print(omg)
# Out:
# Full session finished in 1870.54 second(s)
#     train data size  ...    accuracy
# 0             0.900  ...    0.987640
# 1             0.800  ...    0.986984
# 2             0.700  ...    0.983707
# 3             0.600  ...    0.982442
# 4             0.500  ...    0.980148
# 5             0.400  ...    0.978150
# 6             0.300  ...    0.976001
# 7             0.200  ...    0.971416
# 8             0.100  ...    0.963210
# 9             0.005  ...    0.947818
# 10            0.010  ...    0.882751
#
# [11 rows x 5 columns]

# %% [markdown]
# # New Section
